# %%
//1024
print('Hello World!')

//990
print("1\n2\n3\n4\n5")

//5133
print("a\nbb\nccc")

//4716
a = int(input())
b = int(input())
print(b//a)

//4717
a = int(input())
b = int(input())
print(b % a)

//7401
a = int(input())
print(a-1)

//7943
a, b = input().split()
a = int(a)
b = int(b)

perimeter = 2 * (a + b)

print(perimeter)

//7944
a, b = input().split()
a = int(a)
b = int(b)

perimeter = a * b

print(perimeter)

//1286
a, b, c = input().split()
a = int(a)
b = int(b)
c = int(c)

perimeter = a + b + c

print(perimeter)

//1
ab = int(input())
a = ab // 10;
b = ab %10
print (a, b)

//5175
b = int(input())
b = b %10
print (b)

//906
a = int(input())

product = 1

while a != 0:
    digit = a % 10
    product *= digit
    a //= 10

print(product)

//939
ab = int(input())
a = ab // 10
b = ab % 10
print ((b+a) * (a+b))

//943
a = int(input())
new = 0
while a != 0:
    r = a % 10
    new = new*10 + r
    a //=10
print(new)

//945
abc = int(input())
a = int(abc/100)
b = abc/10%10
c = abc%10
print(a*10 + c)
